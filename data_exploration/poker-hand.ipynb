# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %matplotlib inline

# %%
features = {"S1", "C1", "S2", "C2", "S3", "C3", "S4", "C4", "S5", "C5", "CLASS"}
poker = np.loadtxt(fname="/home/haiqw/Documents/my_projects/iforest/test/poker-hand-testing.data", delimiter=",", dtype=np.int)
poker_data = poker[:, 0:poker.shape[1] - 1]
poker_labels = poker[:, poker.shape[1] - 1]

# %%
poker_data_frame = pd.DataFrame(poker, columns=features)

# %%
sns.set()
sns.pairplot(poker_data_frame.loc[:, ["S1", "C1", "CLASS"]], hue="CLASS")

# %%
plt.show()

# %%
np.unique(poker_labels)
# Out:
# array([0, 1, 2, 3, 4, 5, 6, 7])
