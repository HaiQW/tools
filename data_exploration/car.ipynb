# %% [markdown]
# ## Data Set Describtion
#
# > Predicting the age of abalone from physical measurements.  The age of
#    abalone is determined by cutting the shell through the cone, staining it,
#    and counting the number of rings through a microscope -- a boring and
#    time-consuming task.  Other measurements, which are easier to obtain, are
#    used to predict the age.  Further information, such as weather patterns
#    and location (hence food availability) may be required to solve the problem.
#
# ## Attributes
# | Name        | Values          |
# | ------------- |:-------------:|
# |buying|v-high, high, med, low|
# |maint|v-high, high, med, low|
# |doors|2, 3, 4, 5-more|
# |persons|2, 4, more|
# |lug_boot|small, med, big|
# |safety|low, med, high|

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %matplotlib inline

# %%
features = ["buying", "maint", "doors", "persons", "lug_boot", "safety", "category"]
car = pd.read_csv("/home/haiqw/Documents/my_projects/iforest/test/car.data", header=None, names=features)
print ("Description of the Abalone Dataset")
car.describe()
# Out:
# Description of the Abalone Dataset
#        buying maint doors persons lug_boot safety category
# count    1728  1728  1728    1728     1728   1728     1728
# unique      4     4     4       3        3      3        4
# top       med   med     3    more      med    med    unacc
# freq      432   432   432     576      576    576     1210

# %%
print ("encode the category attributes")
for f in features:
    car[f] = car[f].astype('category')
    car[f] = car[f].cat.codes
car.describe()
# Out:
# encode the category attributes
#             buying        maint        doors      persons     lug_boot  \
# count  1728.000000  1728.000000  1728.000000  1728.000000  1728.000000
# mean      1.500000     1.500000     1.500000     1.000000     1.000000
# std       1.118358     1.118358     1.118358     0.816733     0.816733
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.750000     0.750000     0.750000     0.000000     0.000000
# 50%       1.500000     1.500000     1.500000     1.000000     1.000000
# 75%       2.250000     2.250000     2.250000     2.000000     2.000000
# max       3.000000     3.000000     3.000000     2.000000     2.000000
#
#             safety     category
# count  1728.000000  1728.000000
# mean      1.000000     1.553241
# std       0.816733     0.875948
# min       0.000000     0.000000
# 25%       0.000000     1.000000
# 50%       1.000000     2.000000
# 75%       2.000000     2.000000
# ...

# %%
sns.set()
sns.pairplot(car, hue="category")

# %%
np.savetxt(X=car, fname="/home/haiqw/Documents/my_projects/iforest/test/car.txt")

# %%
indices = np.loadtxt("/home/haiqw/Documents/my_projects/iforest/idx.txt")
# print abalone.query(" Rings == 4")
cnt = 0
for idx in indices:
    cnt += 1
    if (car.loc[idx, "category"] == 3):
        print (car.loc[idx, "category"], "cnt:", cnt)
# Out:
# (3, 'cnt:', 318)
# (3, 'cnt:', 355)
# (3, 'cnt:', 386)
# (3, 'cnt:', 397)
# (3, 'cnt:', 404)
# (3, 'cnt:', 406)
# (3, 'cnt:', 461)
# (3, 'cnt:', 482)
# (3, 'cnt:', 529)
# (3, 'cnt:', 576)
# (3, 'cnt:', 586)
# (3, 'cnt:', 592)
# (3, 'cnt:', 735)
# (3, 'cnt:', 737)
# (3, 'cnt:', 759)
# (3, 'cnt:', 771)
# (3, 'cnt:', 789)
# (3, 'cnt:', 792)
# (3, 'cnt:', 804)
# (3, 'cnt:', 809)
# (3, 'cnt:', 816)
# (3, 'cnt:', 830)
# (3, 'cnt:', 836)
# (3, 'cnt:', 847)
# (3, 'cnt:', 921)
# (3, 'cnt:', 923)
# (3, 'cnt:', 943)
# (3, 'cnt:', 945)
# (3, 'cnt:', 950)
# (3, 'cnt:', 952)
# (3, 'cnt:', 962)
# (3, 'cnt:', 964)
# (3, 'cnt:', 967)
# (3, 'cnt:', 971)
# (3, 'cnt:', 978)
# (3, 'cnt:', 981)
# (3, 'cnt:', 1038)
# (3, 'cnt:', 1040)
# (3, 'cnt:', 1045)
# (3, 'cnt:', 1047)
# (3, 'cnt:', 1422)
# (3, 'cnt:', 1425)
# (3, 'cnt:', 1426)
# (3, 'cnt:', 1443)
# (3, 'cnt:', 1451)
# (3, 'cnt:', 1453)
# (3, 'cnt:', 1459)
# (3, 'cnt:', 1468)
# (3, 'cnt:', 1489)
# (3, 'cnt:', 1506)
# (3, 'cnt:', 1510)
# ...
