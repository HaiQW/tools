# %% [markdown]
# ## Shuttle Data Set
#
# >The shuttle dataset contains 9 attributes all of which are numerical.
#  The first one being time. Approximately 80% of the data belongs to class 1. Therefore the default
#  accuracy is about 80%. The aim here is to obtain an accuracy of
#  99 - 99.9%.  The last column is the class which has been
#  coded as follows :
#
# |Value|Description        |
# |-------------|:-----|
# |1|Rad Flow|
# |2|Fpv Close|
# |3|Fpv Open|
# |4|High|
# |5|Bypass|
# |6|Bpv Close|
# |7|Bpv Open|

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %matplotlib inline

# %%
features = ["1", "2", "3", "4", "5", "6", "7", "8", "9", "category"]
shuttle = pd.read_csv("/home/haiqw/Documents/my_projects/iforest/test/shuttle.trn", names=features, delimiter="\s+", header=None)
print ("Description of the Abalone Dataset")
shuttle.describe()
# Out:
# Description of the Abalone Dataset
#                   1             2             3             4             5  \
# count  43500.000000  43500.000000  43500.000000  43500.000000  43500.000000
# mean      48.249747     -0.205126     85.341563      0.262736     34.528782
# std       12.252618     78.142770      8.908602     41.004131     21.703409
# min       27.000000  -4821.000000     21.000000  -3939.000000   -188.000000
# 25%       38.000000      0.000000     79.000000      0.000000     26.000000
# 50%       45.000000      0.000000     83.000000      0.000000     42.000000
# 75%       55.000000      0.000000     89.000000      0.000000     46.000000
# max      126.000000   5075.000000    149.000000   3830.000000    436.000000
#
#                   6             7             8             9      category
# count  43500.000000  43500.000000  43500.000000  43500.000000  43500.000000
# mean       1.298276     37.074552     50.899862     13.964598      1.700529
# ...

# %%
sns.set()
sns.pairplot(shuttle.query("category == 1 or category == 4"), hue="category")

# %%
shuttle.shape
# Out:
# (43500, 10)
