# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt

# %matplotlib inline

# %% [markdown]
# ## Wine Dataset
#
# > The data was used with many others for comparing various
#    classifiers. The classes are separable, though only RDA
#    has achieved 100% correct classification.
#    (RDA : 100%, QDA 99.4%, LDA 98.9%, 1NN 96.1% (z-transformed data))
#    (All results using the leave-one-out technique). In a classification context, this is a well posed problem
#    with "well behaved" class structures. A good data set
#    for first testing of a new classifier, but not very
#
# ## Attributes
#
# | Name        | Data Type           | Means  |Description  |
# | ------------- |:-------------:| -----:|-----:|
# |Sex|nominal| |M, F, and I (infant)|
# |Length|continuous|mm|Longest shell measurement|
# |Diameter|continuous|mm|perpendicular to length
# |Height|continuous|mm|with meat in shell|
# |Whole weight|continuous|grams|whole abalone|
# |Shucked weight|continuous|grams|weight of meat|
# |Viscera weight|continuous|grams|gut weight (after bleeding)|
# |Shell weight|continuous|grams|after being dried|
# |Rings|integer| |+1.5 gives the age in years|

# %%
features = ["Sex", "Length", "Diameter", "Height", "WholeWeight", "ShuckedWeight", "VisceraWeight", "ShellWeight", "Rings"]
abalone = pd.read_csv("/home/haiqw/Documents/my_projects/iforest/test/abalone.data", header=None, names=features)
print ("Description of the Abalone Dataset")
abalone.describe()
# Out:
# Description of the Abalone Dataset
#             Length     Diameter       Height  WholeWeight  ShuckedWeight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000    4177.000000
# mean      0.523992     0.407881     0.139516     0.828742       0.359367
# std       0.120093     0.099240     0.041827     0.490389       0.221963
# min       0.075000     0.055000     0.000000     0.002000       0.001000
# 25%       0.450000     0.350000     0.115000     0.441500       0.186000
# 50%       0.545000     0.425000     0.140000     0.799500       0.336000
# 75%       0.615000     0.480000     0.165000     1.153000       0.502000
# max       0.815000     0.650000     1.130000     2.825500       1.488000
#
#        VisceraWeight  ShellWeight        Rings
# count    4177.000000  4177.000000  4177.000000
# mean        0.180594     0.238831     9.933684
# std         0.109614     0.139203     3.224169
# min         0.000500     0.001500     1.000000
# ...

# %%
sns.set()
sns.pairplot(abalone.query("4 <= Rings <= 15"), hue="Rings")

# %%
np.savetxt(X=abalone.query("4 <= Rings <= 15").loc[:, ["WholeWeight", "ShuckedWeight", "VisceraWeight", "ShellWeight", "Rings"]], fname="/home/haiqw/Documents/my_projects/iforest/abalone.txt", fmt="%.3f")
abalone = pd.read_csv("/home/haiqw/Documents/my_projects/iforest/abalone.txt", header=None, names=["WholeWeight", "ShuckedWeight", "VisceraWeight", "ShellWeight", "Rings"], delimiter=" ")

# %%
indices = np.loadtxt("/home/haiqw/Documents/my_projects/iforest/idx.txt")
# print abalone.query(" Rings == 4")
cnt = 0
for idx in indices:
    cnt += 1
    if (abalone.loc[idx, "Rings"] == 4):
        print (abalone.loc[idx, "Rings"], "cnt:", cnt)
# Out:
# (4.0, 'cnt:', 321)
# (4.0, 'cnt:', 434)
# (4.0, 'cnt:', 492)
# (4.0, 'cnt:', 551)
# (4.0, 'cnt:', 558)
# (4.0, 'cnt:', 623)
# (4.0, 'cnt:', 709)
# (4.0, 'cnt:', 730)
# (4.0, 'cnt:', 732)
# (4.0, 'cnt:', 733)
# (4.0, 'cnt:', 739)
# (4.0, 'cnt:', 777)
# (4.0, 'cnt:', 787)
# (4.0, 'cnt:', 833)
# (4.0, 'cnt:', 904)
# (4.0, 'cnt:', 938)
# (4.0, 'cnt:', 983)
# (4.0, 'cnt:', 1009)
# (4.0, 'cnt:', 1060)
# (4.0, 'cnt:', 1061)
# (4.0, 'cnt:', 1148)
# (4.0, 'cnt:', 1184)
# (4.0, 'cnt:', 1187)
# (4.0, 'cnt:', 1204)
# (4.0, 'cnt:', 1220)
# (4.0, 'cnt:', 1226)
# (4.0, 'cnt:', 1234)
# (4.0, 'cnt:', 1266)
# (4.0, 'cnt:', 1337)
# (4.0, 'cnt:', 1345)
# (4.0, 'cnt:', 1348)
# (4.0, 'cnt:', 1362)
# (4.0, 'cnt:', 1422)
# (4.0, 'cnt:', 1430)
# (4.0, 'cnt:', 1453)
# (4.0, 'cnt:', 1454)
# (4.0, 'cnt:', 1455)
# (4.0, 'cnt:', 1456)
# (4.0, 'cnt:', 1457)
# (4.0, 'cnt:', 1491)
# (4.0, 'cnt:', 1513)
# (4.0, 'cnt:', 1548)
# (4.0, 'cnt:', 1556)
# (4.0, 'cnt:', 1561)
# (4.0, 'cnt:', 1672)
# (4.0, 'cnt:', 1686)
# ...
